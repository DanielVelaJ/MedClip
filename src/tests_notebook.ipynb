# %%
from preprocess.pipelines import make_pipeline
import matplotlib.pyplot as plt
from PIL import Image

# %%
a=make_pipeline('../data/intermediate/inter_medpix.csv')
# Out:
# making input pipeline

# %%
b=make_pipeline('../data/intermediate/inter_medpix.csv')
# Out:
# making input pipeline

# %%
for img in a['CLIP']['val'].take(2).map(lambda a: a['image']):
    plt.imshow(img)

# %%
Image.open(a['CLIP']['val_img_paths'][1])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=490x399>

# %%
a
# Out:
# {'CLIP': {'train': <ZipDataset element_spec=({'image': TensorSpec(shape=(299, 299, 3), dtype=tf.float32, name=None), 'text': TensorSpec(shape=(), dtype=tf.string, name=None)},)>,
#   'val': <ZipDataset element_spec=({'image': TensorSpec(shape=(299, 299, 3), dtype=tf.float32, name=None), 'text': TensorSpec(shape=(), dtype=tf.string, name=None)},)>,
#   'test': <ZipDataset element_spec=({'image': TensorSpec(shape=(299, 299, 3), dtype=tf.float32, name=None), 'text': TensorSpec(shape=(), dtype=tf.string, name=None)},)>,
#   'train_img_paths': ['../data/raw/medpix/Images/4600.jpg',
#    '../data/raw/medpix/Images/15276.jpg',
#    '../data/raw/medpix/Images/8476.jpg',
#    '../data/raw/medpix/Images/1496.jpg',
#    '../data/raw/medpix/Images/9022.jpg',
#    '../data/raw/medpix/Images/25154.jpg',
#    '../data/raw/medpix/Images/33641.jpg',
#    '../data/raw/medpix/Images/34759.jpg',
#    '../data/raw/medpix/Images/7990.jpg',
#    '../data/raw/medpix/Images/28528.jpg',
# ...
